# %% [markdown]
# # 🚀 Running PDDikti Dashboard on Google Colab
#
# Gunakan notebook ini jika Anda ingin menjalankan Dashboard tanpa instal Python di laptop sendiri.
#
# ### **Langkah-langkah:**
# 1.  Pastikan semua file (`app.py`, `scraper/`, `static/`, `templates/`, `requirements.txt`) sudah diupload ke sesi Colab ini (klik ikon folder di kiri, lalu tarik folder ke sana).
# 2.  Jalankan cell di bawah ini satu per satu.
# 3.  Klik link yang muncul untuk membuka Dashboard.

# %% [markdown]
# ### **1. Instal Library yang Dibutuhkan**

# %%
# !pip install -r requirements.txt
print("✅ Instalasi selesai!")

# %% [markdown]
# ### **2. Jalankan Server Dashboard**
# Setelah menjalankan cell ini, akan muncul link di bagian bawah (biasanya berakhiran `.colab.googleusercontent.com`). Klik link tersebut!

# %%
from google.colab import output
import os

# Buat folder output jika belum ada
os.makedirs("output", exist_ok=True)

# Aktifkan port 5000 agar bisa diakses dari luar
output.serve_kernel_port(5000)

print("🌐 Klik link di atas untuk membuka Dashboard!")
print("⚠️ Jangan stop cell ini selama Anda masih memakai dashboard.\n")

# !python app.py
